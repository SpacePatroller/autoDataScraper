# %%
#import packages 
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
#url to navigate to 
#URL = "https://realpython.github.io/fake-jobs/"
URL = "https://www.cars.com/shopping/results/?body_style_slugs[]=coupe&dealer_id=&keyword=&list_price_max=&list_price_min=&makes[]=bmw&maximum_distance=all&mileage_max=&page=1&page_size=100&sort=distance&stock_type=used&transmission_slugs[]=manual&year_max=&year_min=&zip=63110"
page = requests.get(URL)

# %%
soup = BeautifulSoup(page.content, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="ep-theme-cars" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title data-suffix=" | Cars.com">Used BMW for Sale Near Me | Cars.com</title>
# <meta content="Shop BMW vehicles for sale at Cars.com. Research, compare, and save listings, or contact sellers directly from 918 BMW models nationwide." name="description"/>
# <meta content="noindex, nofollow" name="robots"/>
# <meta content="Cars.com" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <meta content="Used BMW for Sale Near Me | Cars.com" property="og:title"/>
# <meta content="https://www.cars.com/shopping/results" property="og:url"/>
# <meta content="Shop BMW vehicles for sale at Cars.com. Research, compare, and save listings, or contact sellers directly from 918 BMW models nationwide." property="og:description"/>
# ...
